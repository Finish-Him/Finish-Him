# %% [markdown]
# # 📥 Baixar Gemma Chat para Google Drive
#
# Pasta: `1zhorJ03BIV3T5C-HlJVRaFGwLfe8vl2p`

# %%
from google.colab import drive
drive.mount('/content/drive')
print('✅')

# %%
# !git clone --depth 1 https://github.com/Finish-Him/gemma-3-4b-chat.git /tmp/gemma 2>/dev/null
print('✅ Repo clonado')

# %%
import shutil, os
d = '/content/drive/My Drive/BAML'
os.makedirs(d, exist_ok=True)
[shutil.copy(f'{d.replace("/content/drive/My Drive/BAML","/tmp/gemma")}/{f}', f'{d}/{f}') for f in ['gemma-3-4b-chat.ipynb','gemma-1b-chat.ipynb'] if os.path.exists(f'/tmp/gemma/{f}')]
print('✅ Salvo!')

# %% [markdown]
# Abra em: `/content/drive/My Drive/BAML/`
