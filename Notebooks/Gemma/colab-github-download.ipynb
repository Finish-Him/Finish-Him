# %% [markdown]
# # 📥 Baixar Arquivos BAML do GitHub
#
# Este notebook baixa os arquivos do repositório BAML do GitHub para o Google Drive.
#
# ## Passo a passo:
# 1. Conectar Google Drive
# 2. Clonar repositório GitHub
# 3. Copiar notebooks para o Drive

# %%
# 1. Conectar Google Drive
from google.colab import drive
drive.mount('/content/drive')
print('✅ Drive conectado!')

# %%
# 2. Criar pasta BAML no Drive
import os
baml_path = '/content/drive/My Drive/BAML'
os.makedirs(baml_path, exist_ok=True)
print(f'📁 Pasta criada: {baml_path}')

# %%
# 3. Clonar repositório
# !git clone https://github.com/Finish-Him/Finish-Him.git /tmp/baml-repo
print('✅ Repositório clonado!')

# %%
# 4. Copiar arquivos BAML
import shutil

files_to_copy = [
    '/tmp/baml-repo/baterias-rj/README.md',
]

# Criar subpasta
colab_path = f'{baml_path}/Colab'
os.makedirs(colab_path, exist_ok=True)

print('📋 Arquivos disponíveis no repo:')
# !ls /tmp/baml-repo/

# %%
# Mostrar onde estão os notebooks
print('🔍 Buscando notebooks na pasta BAML...')
# !find /tmp/baml-repo -name "*.ipynb" 2>/dev/null | head -10

print('\n🔍 Buscando arquivos .sh...')
# !find /tmp/baml-repo -name "*.sh" 2>/dev/null | head -10
